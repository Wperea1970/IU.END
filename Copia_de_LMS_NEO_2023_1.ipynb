# %% [markdown]
# <a href="https://colab.research.google.com/github/Wperea1970/IU.END/blob/master/Copia_de_LMS_NEO_2023_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xlrd
import gspread_dataframe
import plotly.express as px
import altair as alt
from pandas.core.groupby import groupby
import plotly.graph_objects as go

# %%
info= pd.read_excel("InformeLMSNEO2023-2.xlsx")
info.head(5).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_8b053_row0_col2, #T_8b053_row0_col3, #T_8b053_row0_col5, #T_8b053_row0_col6, #T_8b053_row0_col7, #T_8b053_row0_col8, #T_8b053_row0_col9, #T_8b053_row0_col10, #T_8b053_row0_col11, #T_8b053_row0_col12, #T_8b053_row1_col2, #T_8b053_row1_col3, #T_8b053_row1_col6, #T_8b053_row1_col7, #T_8b053_row1_col9, #T_8b053_row1_col10, #T_8b053_row1_col11, #T_8b053_row1_col12, #T_8b053_row2_col2, #T_8b053_row2_col5, #T_8b053_row2_col7, #T_8b053_row2_col9, #T_8b053_row2_col10, #T_8b053_row2_col11, #T_8b053_row2_col12, #T_8b053_row3_col2, #T_8b053_row3_col3, #T_8b053_row3_col4, #T_8b053_row3_col5, #T_8b053_row3_col6, #T_8b053_row3_col7, #T_8b053_row3_col8, #T_8b053_row3_col9, #T_8b053_row3_col10, #T_8b053_row3_col11, #T_8b053_row3_col12, #T_8b053_row4_col2, #T_8b053_row4_col3, #T_8b053_row4_col6, #T_8b053_row4_col7, #T_8b053_row4_col8, #T_8b053_row4_col9, #T_8b053_row4_col11, #T_8b053_row4_col12 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# ...

# %%
info.round(2).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro general por programa, docentes y actividades planeadas 2023-1*</b></font></center>

# %%
col_a_sumar = ['Test','Actividad fuera de línea','Espacio en la nube para subir archivos','Ejercicio escrito online (Ensayo)','Encuesta','Debate','Discusión',]
info[col_a_sumar].sum()
# Out:
# Test                                      2659
# Actividad fuera de línea                  2748
# Espacio en la nube para subir archivos    2655
# Ejercicio escrito online (Ensayo)         3396
# Encuesta                                    23
# Debate                                      35
# Discusión                                  277
# dtype: int64

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Porcentaje de las actividades planeadas 2023-1'

fig = px.pie(values =[2659,2748,2655,3396,23,35,277],

             names = ['Test','Actividad fuera de línea','Espacio en la nube para subir archivos','Ejercicio escrito online (Ensayo)','Encuesta','Debate','Discusión'],
             title=title)

color = ['G3','G4','G5','G6','G3','G7','G8','G9']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Medidas de tendencia central de las actividades planeadas 2023-1*</b></font></center>

# %%
info.describe().round(2)
# Out:
#        Clase    Test  Ejercicio escrito online (Ensayo)  \
# count  403.0  403.00                             403.00
# mean     0.0    6.60                               8.43
# std      0.0   22.34                              27.16
# min      0.0    0.00                               0.00
# 25%      0.0    0.00                               0.00
# 50%      0.0    0.00                               0.00
# 75%      0.0    2.00                               2.00
# max      0.0  227.00                             257.00
#
#        Actividad fuera de línea  Espacio en la nube para subir archivos  \
# count                    403.00                                  403.00
# mean                       6.82                                    6.59
# std                       30.06                                   17.77
# min                        0.00                                    0.00
# 25%                        0.00                                    0.00
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Total de actividades planeadas por programa académico 2023-1*</b></font></center>

# %%
info.groupby("Organización").sum().style.background_gradient(axis=0)
# Out:
# <ipython-input-8-298fefe7b13d>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <style type="text/css">
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Desviación Standar de las actividades planeadas 2023-1*</b></font></center>

# %%
info.std()
# Out:
# <ipython-input-9-eb242f4f2d94>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# Clase                                      0.000000
# Test                                      22.336798
# Ejercicio escrito online (Ensayo)         27.160505
# Actividad fuera de línea                  30.063108
# Espacio en la nube para subir archivos    17.765584
# Encuesta                                   0.762438
# Discusión                                  3.342998
# Debate                                     0.606680
# Equipo                                     4.541507
# SCORM                                      0.649242
# Asistencia                                 0.157407
# dtype: float64

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Valor máximo de las actividades planeadas 2023-1*</b></font></center>

# %%
info.max()
# Out:
# Organización                                         Terapia ocupacional
# Docente                                   Zuniga Bolivar, Sandra Marcela
# Clase                                                                  0
# Test                                                                 227
# Ejercicio escrito online (Ensayo)                                    257
# Actividad fuera de línea                                             262
# Espacio en la nube para subir archivos                               180
# Encuesta                                                              15
# Discusión                                                             34
# Debate                                                                 9
# Equipo                                                                50
# SCORM                                                                  9
# Asistencia                                                             3
# dtype: object

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Valor mínimo de las actividades planeadas 2023-1*</b></font></center>

# %%
info.min()
# Out:
# Organización                              Administración de empresas
# Docente                                        Abella Leon, Carolina
# Clase                                                              0
# Test                                                               0
# Ejercicio escrito online (Ensayo)                                  0
# Actividad fuera de línea                                           0
# Espacio en la nube para subir archivos                             0
# Encuesta                                                           0
# Discusión                                                          0
# Debate                                                             0
# Equipo                                                             0
# SCORM                                                              0
# Asistencia                                                         0
# dtype: object

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Promedio de las actividades planeadas 2023-1*</b></font></center>

# %%
info.mean()
# Out:
# <ipython-input-12-c149b9ad16c9>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# Clase                                     0.000000
# Test                                      6.598015
# Ejercicio escrito online (Ensayo)         8.426799
# Actividad fuera de línea                  6.818859
# Espacio en la nube para subir archivos    6.588089
# Encuesta                                  0.057072
# Discusión                                 0.687345
# Debate                                    0.086849
# Equipo                                    1.039702
# SCORM                                     0.062035
# Asistencia                                0.009926
# dtype: float64

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Porcentaje  de actividades planeadas por programa 2023-1*</b></font></center>

# %%
#info.groupby('Organización')[['Test','Ejercicio escrito online (Ensayo)', 'Actividad fuera de línea', 'Test', 'Debate']].mean()
round(info.groupby('Organización')[['Test','Ejercicio escrito online (Ensayo)', 'Actividad fuera de línea', 'Test', 'Debate']].mean(), 3)
#info.set_option('precision', 2)
# Out:
#                                                       Test  \
# Organización
# Administración de empresas                           0.714
# Centro de Idiomas                                   14.450
# Deporte                                             13.224
# Especialización Actividad física                     0.222
# Especialización Fisioterapia del deporte             1.231
# Especialización Neuro Rehabilitación                 0.467
# Especialización Teoría y metodología del entren...   1.312
# Especialización en Mercadeo Deportivo                0.000
# Especialización en dirección y gestión deportiva     0.000
# Especialización en periodismo deportivo              0.000
# FACULTAD DE CIENCIAS DE LA EDUCACIÓN Y DEL DEPORTE   0.000
# FACULTAD DE CIENCIAS ECONÓMICAS Y DE LA ADMNIST...   0.000
# FACULTAD DE SALUD Y REHABILITACÓN                    0.000
# Fisioterapia                                         9.744
# INSTITUCIÓN UNIVERSITARIA ESCUELA NACIONAL DEL ...   0.846
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
data = {'Actividades': ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea','Debate'],
        'Administración de empresas':[20,1389,189,0],
        'Deporte':[1005,933,1071,11],
        'Fisioterapia':[760,107,27,4],
        'Nutrición y dietética':[47,32,92,3],
        'Tecnología Cali':[383,147,294,5],
        'Terapia ocupacional':[78,95,16,0],
        'Tecnología en gestión Deportiva':[36,116,126,1],
        'Especialización Actividad física	':[0,2,2,0],
        'Especialización Fisioterapia del deporte':	[11,0,16,0],
        'Especialización Neuro Rehabilitación':[49,	2,7	,0],
        'Especialización Teoría y metodología del entrenamiento':[72,17,21,	0],
        'Especialización en Mercadeo Deportivo':[1,0,0,0],
        'Especialización en dirección y gestión deportiva':[14,52,0,0],
        'Especialización en periodismo deportivo':[	0,	0,	0,	0]}

df = pd.DataFrame(data)

# Configurar las etiquetas como el índice del DataFrame
df.set_index('Actividades', inplace=True)

# Transponer el DataFrame para intercambiar filas y columnas
df = df.T

plt.figure(figsize=(20, 8))

# Crear el gráfico de barras horizontales
df.plot(kind='barh')

# Ajustar el diseño del gráfico
plt.xlabel('Valores')
plt.ylabel('Actividades')
plt.title('Frecuencia de actividades programadas por programa')

# Mostrar el gráfico
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning:
#
# Glyph 9 (	) missing from current font.

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Programa de Admnistración de Empresas*</b></font></center>

# %%
info[info['Organización'] == 'Administración de empresas'].head(25).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Administración de empresas'].sum()
# Out:
# Organización                              Administración de empresasAdministración de em...
# Docente                                   Amaya Sanchez, Blanca EsnedaCardenas Vasquez, ...
# Clase                                                                                     0
# Test                                                                                     20
# Ejercicio escrito online (Ensayo)                                                      1389
# Actividad fuera de línea                                                                189
# Espacio en la nube para subir archivos                                                   63
# Encuesta                                                                                  0
# Discusión                                                                                35
# Debate                                                                                    0
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Actividades planificadas en el programa de Administración de Empresas 2023-1'

fig = px.pie(values =[20,1389,189,63,0,35,0,33],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Encuesta','Discusión','Debate','Equipo'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7','G8','G9']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Promedio de las actividades del programa de  Admnistración de Empresas 2023-1*</b></font></center>

# %%
info[info['Organización'] == 'Administración de empresas'].mean()
# Out:
# <ipython-input-18-bcb50170a576>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# Clase                                      0.000000
# Test                                       0.714286
# Ejercicio escrito online (Ensayo)         49.607143
# Actividad fuera de línea                   6.750000
# Espacio en la nube para subir archivos     2.250000
# Encuesta                                   0.000000
# Discusión                                  1.250000
# Debate                                     0.000000
# Equipo                                     1.178571
# SCORM                                      0.000000
# Asistencia                                 0.000000
# dtype: float64

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro del programa de Deporte, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Deporte'].head(80).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Deporte'].sum()
# Out:
# Organización                              DeporteDeporteDeporteDeporteDeporteDeporteDepo...
# Docente                                   Aponte Salcedo, Gabriel EduadoArbelaez Arenas,...
# Clase                                                                                     0
# Test                                                                                   1005
# Ejercicio escrito online (Ensayo)                                                       933
# Actividad fuera de línea                                                               1071
# Espacio en la nube para subir archivos                                                 1247
# Encuesta                                                                                  3
# Discusión                                                                               147
# Debate                                                                                   11
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Actividades planificadas en el programa de Deporte 2023-1'

fig = px.pie(values =[1005,933,1071,1247,3,147,11,103],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Encuesta','Discusión','Debate','Equipo'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7','G8','G9']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro del programa de Fisoterapia, docente y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Fisioterapia'].head(80).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Fisioterapia' ].sum()
# Out:
# Organización                              FisioterapiaFisioterapiaFisioterapiaFisioterap...
# Docente                                   Alegria Lopez, Diana MariaAlvarez Agudelo, Jul...
# Clase                                                                                     0
# Test                                                                                    760
# Ejercicio escrito online (Ensayo)                                                       107
# Actividad fuera de línea                                                                 27
# Espacio en la nube para subir archivos                                                  381
# Encuesta                                                                                 16
# Discusión                                                                                 4
# Debate                                                                                    4
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Actividades planificadas en el programa de Fisioterapia 2023-1'

fig = px.pie(values =[760,107,27,381,16,4,4,182],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Encuesta','Discusión','Debate','Equipo'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7','G8','G9']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro del programa de Nutrición y dietética, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Nutrición y Dietética' ].head(50).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Nutrición y Dietética' ].sum()
# Out:
# Organización                              Nutrición y DietéticaNutrición y DietéticaNutr...
# Docente                                   Aguirre Santafe, Luz AdrianaAlfaro Barragan, S...
# Clase                                                                                     0
# Test                                                                                     92
# Ejercicio escrito online (Ensayo)                                                        47
# Actividad fuera de línea                                                                 32
# Espacio en la nube para subir archivos                                                  321
# Encuesta                                                                                  2
# Discusión                                                                                 7
# Debate                                                                                    3
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Actividades planificadas en el programa de Nutrición y Dietética 2023-1'

fig = px.pie(values =[92,47,32,321,2,7,3,6],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Encuesta','Discusión','Debate','Equipo'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7','G8','G9']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro del programa de Terapaia ocupacional, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Terapia ocupacional'].head(40).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Terapia ocupacional'].sum()
# Out:
# Organización                              Terapia ocupacionalTerapia ocupacionalTerapia ...
# Docente                                   Abella Leon, CarolinaAgudelo Orozco, Alexander...
# Clase                                                                                     0
# Test                                                                                     16
# Ejercicio escrito online (Ensayo)                                                        78
# Actividad fuera de línea                                                                 95
# Espacio en la nube para subir archivos                                                  105
# Encuesta                                                                                  0
# Discusión                                                                                 9
# Debate                                                                                    0
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Actividades planificadas en el programa de Terapia Ocupacional 2023-1'

fig = px.pie(values =[16,78,95,105,9,0],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Discusión','Debate'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro del progrma de Tecnología Cali, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Tecnología Cali'].head(25).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Tecnología Cali'].sum()
# Out:
# Organización                              Tecnología CaliTecnología CaliTecnología CaliT...
# Docente                                   Agudelo Bravo, JoharFajardo Colorado, Myriam D...
# Clase                                                                                     0
# Test                                                                                    294
# Ejercicio escrito online (Ensayo)                                                       383
# Actividad fuera de línea                                                                147
# Espacio en la nube para subir archivos                                                  218
# Encuesta                                                                                  0
# Discusión                                                                                59
# Debate                                                                                    5
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Porcentaje de actividades planeadas del programa de Tecnología Cali 2023-1'

fig = px.pie(values =[294,383,147,218,0,59,5],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Encuesta','Discusión','Debate'],
             title=title)

color = ['G4','G5','G6','G3','G2','G7','G8']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro de del programa de Tecnología en gestión deportiva, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Tecnología en gestión Deportiva'].head(25).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_7ab46_row0_col2, #T_7ab46_row0_col3, #T_7ab46_row0_col7, #T_7ab46_row0_col8, #T_7ab46_row0_col9, #T_7ab46_row0_col10, #T_7ab46_row0_col11, #T_7ab46_row0_col12, #T_7ab46_row1_col2, #T_7ab46_row1_col4, #T_7ab46_row1_col7, #T_7ab46_row1_col11, #T_7ab46_row1_col12, #T_7ab46_row2_col2, #T_7ab46_row2_col5, #T_7ab46_row2_col6, #T_7ab46_row2_col7, #T_7ab46_row2_col8, #T_7ab46_row2_col9, #T_7ab46_row2_col10, #T_7ab46_row2_col11, #T_7ab46_row2_col12 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7ab46_row0_col4 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_7ab46_row0_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_7ab46_row0_col6, #T_7ab46_row1_col3, #T_7ab46_row1_col5, #T_7ab46_row1_col6, #T_7ab46_row1_col8, #T_7ab46_row1_col9, #T_7ab46_row1_col10, #T_7ab46_row2_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7ab46_row2_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# </style>
# ...

# %%
info[info['Organización'] == 'Tecnología en gestión Deportiva'].sum()
# Out:
# Organización                              Tecnología en gestión DeportivaTecnología en g...
# Docente                                   Bolanos Cardenas, Cesar LeonardoCano Moya, Joh...
# Clase                                                                                     0
# Test                                                                                    126
# Ejercicio escrito online (Ensayo)                                                        36
# Actividad fuera de línea                                                                116
# Espacio en la nube para subir archivos                                                   50
# Encuesta                                                                                  0
# Discusión                                                                                 1
# Debate                                                                                    1
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Porcentaje de actividades planeadas del programa de Tecnología en Gestión Deportiva 2023-1'


fig = px.pie(values =[126,36,116,50,0,1,1],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Encuesta','Discusión','Debate'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G8','G7']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro de la Especialización en Actividad física, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Especialización Actividad física'].head(25).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Especialización Actividad física'].sum()
# Out:
# Organización                              Especialización Actividad físicaEspecializació...
# Docente                                   Avila Valencia, Juan CarlosBonilla Otalora, Ir...
# Clase                                                                                     0
# Test                                                                                      2
# Ejercicio escrito online (Ensayo)                                                         0
# Actividad fuera de línea                                                                  2
# Espacio en la nube para subir archivos                                                    0
# Encuesta                                                                                  0
# Discusión                                                                                 0
# Debate                                                                                    0
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Actividades planeadas en la Especialización en Actividad Física  2023-1'

fig = px.pie(values =[2,0,2,0,0,0],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Discusión','Debate'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro de la Especialización en dirección y gestión deportiva, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Especialización en dirección y gestión deportiva'].head(25).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Especialización en dirección y gestión deportiva'].sum()
# Out:
# Organización                              Especialización en dirección y gestión deporti...
# Docente                                   Betancourth Guerrero, BenjaminBuitrago Echever...
# Clase                                                                                     0
# Test                                                                                      0
# Ejercicio escrito online (Ensayo)                                                        14
# Actividad fuera de línea                                                                 52
# Espacio en la nube para subir archivos                                                    1
# Encuesta                                                                                  0
# Discusión                                                                                 0
# Debate                                                                                    0
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Actividades planeadas en la Especialización en Dirección y Gestión Deportiva 2023-1'

fig = px.pie(values =[14,52,1,0,0,0],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Discusión','Debate'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro de la Especialización en Mercadeo deportivo, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Especialización en Mercadeo Deportivo'].head().style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_4e8ed_row0_col2, #T_4e8ed_row0_col3, #T_4e8ed_row0_col4, #T_4e8ed_row0_col5, #T_4e8ed_row0_col6, #T_4e8ed_row0_col7, #T_4e8ed_row0_col8, #T_4e8ed_row0_col9, #T_4e8ed_row0_col10, #T_4e8ed_row0_col11, #T_4e8ed_row0_col12, #T_4e8ed_row1_col2, #T_4e8ed_row1_col3, #T_4e8ed_row1_col4, #T_4e8ed_row1_col5, #T_4e8ed_row1_col6, #T_4e8ed_row1_col7, #T_4e8ed_row1_col8, #T_4e8ed_row1_col9, #T_4e8ed_row1_col10, #T_4e8ed_row1_col11, #T_4e8ed_row1_col12, #T_4e8ed_row2_col2, #T_4e8ed_row2_col3, #T_4e8ed_row2_col5, #T_4e8ed_row2_col6, #T_4e8ed_row2_col7, #T_4e8ed_row2_col8, #T_4e8ed_row2_col9, #T_4e8ed_row2_col10, #T_4e8ed_row2_col11, #T_4e8ed_row2_col12 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_4e8ed_row2_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e8ed" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
info[info['Organización'] == 'Especialización en Mercadeo Deportivo'].sum()
# Out:
# Organización                              Especialización en Mercadeo DeportivoEspeciali...
# Docente                                   Jaramillo Gutierrez, DiegoOrozco Lara, Jhon Fe...
# Clase                                                                                     0
# Test                                                                                      0
# Ejercicio escrito online (Ensayo)                                                         1
# Actividad fuera de línea                                                                  0
# Espacio en la nube para subir archivos                                                    0
# Encuesta                                                                                  0
# Discusión                                                                                 0
# Debate                                                                                    0
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Actividades planeadas en la Especialización en Mercadeo Deportivo 2023-1'

fig = px.pie(values =[0,1,0,0,0,0],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Discusión','Debate'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro de la Especialización en Teoría y Metodología del Entrenamiento Deportiva, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Especialización Teoría y metodología del entrenamiento'].head(35).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Especialización Teoría y metodología del entrenamiento'].sum()
# Out:
# Organización                              Especialización Teoría y metodología del entre...
# Docente                                   Agudelo Velasquez, Carlos AlbertoArboleda Fran...
# Clase                                                                                     0
# Test                                                                                     21
# Ejercicio escrito online (Ensayo)                                                        72
# Actividad fuera de línea                                                                 17
# Espacio en la nube para subir archivos                                                   36
# Encuesta                                                                                  2
# Discusión                                                                                 4
# Debate                                                                                    0
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Porcentaje de actividades programadas de la Especialización Teoría y Metodología del Entrenamiento Deportivo 2023-1'

fig = px.pie(values =[21,72,17,36,4,0],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Discusión','Debate'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro de la Especialización en Neuro Rehabilitación, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización'] == 'Especialización Neuro Rehabilitación'].head(25).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización'] == 'Especialización Neuro Rehabilitación'].sum()
# Out:
# Organización                              Especialización Neuro RehabilitaciónEspecializ...
# Docente                                   Agudelo Martinez, Ayda ZulamyAnte Chaves, Cath...
# Clase                                                                                     0
# Test                                                                                      7
# Ejercicio escrito online (Ensayo)                                                        49
# Actividad fuera de línea                                                                  2
# Espacio en la nube para subir archivos                                                    2
# Encuesta                                                                                  0
# Discusión                                                                                 0
# Debate                                                                                    0
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Porcentaje de actividades programadas de la Especialización en Neuro Rehabilitación  2023-1'

fig = px.pie(values =[7,49,2,2,0,0],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Discusión','Debate'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro de la Especialización en Actividad Física, docentes y actividades planeadas*</b></font></center>

# %%
info[info['Organización']== 'Especialización Actividad física'].head(10).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %%
info[info['Organización']== 'Especialización Actividad física'].sum()
# Out:
# Organización                              Especialización Actividad físicaEspecializació...
# Docente                                   Avila Valencia, Juan CarlosBonilla Otalora, Ir...
# Clase                                                                                     0
# Test                                                                                      2
# Ejercicio escrito online (Ensayo)                                                         0
# Actividad fuera de línea                                                                  2
# Espacio en la nube para subir archivos                                                    0
# Encuesta                                                                                  0
# Discusión                                                                                 0
# Debate                                                                                    0
# ...

# %%
from _plotly_utils.basevalidators import TitleValidator
import plotly.express as px
title= 'Porcentaje de actividades progrmadas de la Especialización en Actividad Física 2023-1'

fig = px.pie(values =[2,0,0,2,0,0],

             names = ['Test','Ejercicio escrito online (Ensayo)','Actividad fuera de línea ',
                      'Espacio en la nube para subir archivos','Discusión','Debate'],
             title=title)

color = ['G4', 'G5', 'G6', 'G3','G2','G7']

hole =0.4

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Cuadro de la Especialización en Periodismo Deportivo, docentes y actividades planedas*</b></font></center>

# %%
info[info['Organización'] == 'Especialización en periodismo deportivo'].head(15).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ###El programa de **ESPECIALIZACIÓN DE PERIODISMO DEPORTIVO** no refleja uso de la plataforma LMS NEO, como apoyo educativo para el desarrollo del aprendiazje.

# %% [markdown]
# #<center><font color="164089" style="background-color: lightgrey;"><b>*Relación de docentes por prgrama que no muestran ninguna actividad planeada en el LMS NEO 2023-1*</b></font></center>

# %%
dato1=info['Test']==0
dato2=info['Discusión']==0
dato3=info['Debate']==0
dato4=info['Ejercicio escrito online (Ensayo)']==0
dato5=info['Actividad fuera de línea']==0
dato6=info['Espacio en la nube para subir archivos']==0
info[dato1 & dato2 & dato3 & dato4 & dato5 & dato6 ].head(250)
# Out:
#                    Organización                           Docente   Clase  \
# 3    Administración de empresas       Castillo Garzon, Luis Carlos      0
# 7    Administración de empresas  Czerninski Alvarez, Sergio Andres      0
# 15   Administración de empresas          Grisales Gamboa, Humberto      0
# 24   Administración de empresas               Rojas Ospina, Alexis      0
# 25   Administración de empresas  Sandino Rodriguez, Martha Cecilia      0
# ..                          ...                                ...    ...
# 395         Terapia ocupacional       Sarmiento Ortiz, Angie Milen      0
# 396         Terapia ocupacional  Trujillo Colonia, Claudia Marcela      0
# 399         Terapia ocupacional    Vasquez Santiago, Victor Manuel      0
# 400         Terapia ocupacional       Volveras Pimiento, Katherine      0
# 401         Terapia ocupacional   Zamudio Espinosa, Diana Carolina      0
#
#      Test  Ejercicio escrito online (Ensayo)  Actividad fuera de línea  \
# ...

# %%
info[info['Organización'] == 'Deporte'].head(80).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# ...
